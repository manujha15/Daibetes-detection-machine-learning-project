# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('spam.csv',encoding='ISO-8859-1')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
df.sample()
# Out:
#       v1                                 v2
# 807  ham  Boooo you always work. Just quit.

# %%
df.rename(columns={'v1':'target1','v2':'target2'},inplace=True)

# %%
df.head()
# Out:
#   target1                                            target2
# 0     ham  Go until jurong point, crazy.. Available only ...
# 1     ham                      Ok lar... Joking wif u oni...
# 2    spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3     ham  U dun say so early hor... U c already then say...
# 4     ham  Nah I don't think he goes to usf, he lives aro...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
df['target1']=encoder.fit_transform(df['target1'])

# %%
df.head()
# Out:
#    target1                                            target2
# 0        0  Go until jurong point, crazy.. Available only ...
# 1        0                      Ok lar... Joking wif u oni...
# 2        1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3        0  U dun say so early hor... U c already then say...
# 4        0  Nah I don't think he goes to usf, he lives aro...

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df=df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
plt.pie(df['target1'].value_counts(),labels=['ham','spam'],autopct="%0.3f")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 plt.pie(df['target1'].value_counts(),labels=['ham','spam'],autopct="%0.3f")
#       3 plt.show()
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
 df.shape
# Out:
# (5169, 2)

# %%
df['target2'].value_counts()
# Out:
# target2
# Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...                                               1
# Wake me up at  &lt;#&gt;  am morning:)                                                                                                                        1
# I will reach ur home in  &lt;#&gt;  minutes                                                                                                                   1
# Wait.i will come out.. &lt;#&gt;  min:)                                                                                                                       1
# R u here yet? I'm wearing blue shirt n black pants.                                                                                                           1
#                                                                                                                                                              ..
# ...

# %%
df['target1'].value_counts()
# Out:
# target1
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import nltk
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 import nltk
#
# ModuleNotFoundError: No module named 'nltk'

# %%
nltk.download('punkt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 nltk.download('punkt')
#
# NameError: name 'nltk' is not defined

# %%
df['num_characters']=df['target2'].apply(len)

# %%
df['num_words']=df['target2'].apply(lambda x:len(nltk.word_tokenize(x)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df['num_words']=df['target2'].apply(lambda x:len(nltk.word_tokenize(x)))
#
# File c:\Users\jhama\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# ...

# %%
df['num_sentences']=df['target2'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target1                                            target2  num_characters
# 0        0  Go until jurong point, crazy.. Available only ...             111
# 1        0                      Ok lar... Joking wif u oni...              29
# 2        1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3        0  U dun say so early hor... U c already then say...              49
# 4        0  Nah I don't think he goes to usf, he lives aro...              61

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df[['num_characters','num_words','num_sentences']].describe()
#
# File c:\Users\jhama\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\jhama\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
df[df['target1']==0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.123782       1.820195
# std         56.358207    13.493970       1.383657
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
df[df['target1']==1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.970904
# std         30.137753    7.008418       1.488425
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       9.000000

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
plt.figure(figsize=(12,7))
sns.histplot(df[df['target1']==0]['num_characters'])
sns.histplot(df[df['target1']==1]['num_characters'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 plt.figure(figsize=(12,7))
#       2 sns.histplot(df[df['target1']==0]['num_characters'])
#       3 sns.histplot(df[df['target1']==1]['num_characters'])
#
# NameError: name 'plt' is not defined

# %%
sns.histplot(df[df['target1']==1]['num_characters'],color="red")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 sns.histplot(df[df['target1']==1]['num_characters'],color="red")
#
# NameError: name 'sns' is not defined

# %%
df['num_characters'].value_counts()
# Out:
# num_characters
# 22     91
# 24     91
# 32     90
# 23     86
# 38     82
#        ..
# 375     1
# 431     1
# 2       1
# 790     1
# 273     1
# Name: count, Length: 274, dtype: int64

# %%
sns.pairplot(df,hue='target1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 sns.pairplot(df,hue='target1')
#
# NameError: name 'sns' is not defined

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 sns.heatmap(df.corr(),annot=True)
#
# NameError: name 'sns' is not defined

# %%
import nltk
nltk.download('stopwords')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 import nltk
#       2 nltk.download('stopwords')
#
# ModuleNotFoundError: No module named 'nltk'

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 from nltk.corpus import stopwords
#       2 stopwords.words('english')
#
# ModuleNotFoundError: No module named 'nltk'

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def transform_target2(target2):
  target2=target2.lower()
  target2=nltk.word_tokenize(target2)

  y=[]
  for i in target2:
    if i.isalnum():
      y.append(i)


      target2=y[:]
      y.clear()

      for i in target2:
        if i not in stopwords.words('english'):
          y.append(i)


  return " ".join(y)

# %%
transform_target2("I loved you tube ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 transform_target2("I loved you tube ")
#
# Cell In[41], line 3, in transform_target2(target2)
#       1 def transform_target2(target2):
#       2   target2=target2.lower()
# ----> 3   target2=nltk.word_tokenize(target2)
#       5   y=[]
#       6   for i in target2:
#
# NameError: name 'nltk' is not defined

# %%
df['target2'][1000]
# Out:
# 'No..but heard abt tat..'

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
ps.stem('loving')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 from nltk.stem.porter import PorterStemmer
#       2 ps=PorterStemmer()
#       3 ps.stem('loving')
#
# ModuleNotFoundError: No module named 'nltk'

# %%
df['transformed_target']=df['target2'].apply(transform_target2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df['transformed_target']=df['target2'].apply(transform_target2)
#
# File c:\Users\jhama\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# ...

# %%
df.head()
# Out:
#    target1                                            target2  num_characters
# 0        0  Go until jurong point, crazy.. Available only ...             111
# 1        0                      Ok lar... Joking wif u oni...              29
# 2        1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3        0  U dun say so early hor... U c already then say...              49
# 4        0  Nah I don't think he goes to usf, he lives aro...              61

# %%
from wordcloud import WordCloud
wc=WordCloud(width=500,height=500,min_font_size=10,background_color='white')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 from wordcloud import WordCloud
#       2 wc=WordCloud(width=500,height=500,min_font_size=10,background_color='white')
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
spam_wc=wc.generate(df[df['target1']==1]['target2'].str.cat(sep=""))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 spam_wc=wc.generate(df[df['target1']==1]['target2'].str.cat(sep=""))
#
# NameError: name 'wc' is not defined

# %%
plt.figure(figsize=(15,6))
plt.imshow(spam_wc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 plt.figure(figsize=(15,6))
#       2 plt.imshow(spam_wc)
#
# NameError: name 'plt' is not defined

# %%
ham_wc=wc.generate(df[df['target1']==0]['target2'].str.cat(sep=""))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 ham_wc=wc.generate(df[df['target1']==0]['target2'].str.cat(sep=""))
#
# NameError: name 'wc' is not defined

# %%
plt.figure(figsize=(15,6))
plt.imshow(ham_wc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 plt.figure(figsize=(15,6))
#       2 plt.imshow(ham_wc)
#
# NameError: name 'plt' is not defined

# %%
spam_corpus=[]
for msg in df[df['target1']==1]['transformed_target'].tolist():
  for word in msg.split():
    spam_corpus.append(word)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\jhama\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'transformed_target'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 2
#       1 spam_corpus=[]
# ...

# %%
len(spam_corpus)
# Out:
# 0

# %%
from collections import Counter
sns.barplot(pd.DataFrame(Counter(spam_corpus).most_common(30))[0],)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 2
#       1 from collections import Counter
# ----> 2 sns.barplot(pd.DataFrame(Counter(spam_corpus).most_common(30))[0],)
#       3 plt.xticks(rotation='vertical')
#       4 plt.show()
#
# NameError: name 'sns' is not defined

# %%
ham_corpus=[]
for msg in df[df['target1']==1]['transformed_target'].tolist():
  for word in msg.split():
    spam_corpus.append(word)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\jhama\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'transformed_target'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 2
#       1 ham_corpus=[]
# ...

# %%
len(ham_corpus)
# Out:
# 0

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv=CountVectorizer
tfidf=TfidfVectorizer(max_features=3000)

# %%
x=df['target1'].values

# %%
 y=df['target'].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\jhama\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'target'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 y=df['target'].values
#
# ...

# %%
print(x)
# Out:
# [0 0 1 ... 0 0 0]

# %%
x.shape
# Out:
# (5169,)

# %%
y.shape
# Out:
# (5169,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
x_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
x_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train = x_train.reshape(-1, 1)
x_test = x_test.reshape(-1, 1)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier,ExtraTreesClassifier

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()
dt=DecisionTreeClassifier()
rf=RandomForestClassifier()
Ada=AdaBoostClassifier()
ET=ExtraTreesClassifier()
sc=SVC()

# %%
mnb.fit(x_train,y_train)
y_pred2=mnb.predict(x_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.8665377176015474
# [[896   0]
#  [138   0]]
# 0.0
# c:\Users\jhama\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
bnb.fit(x_train,y_train)
y_pred3=bnb.predict(x_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 1.0
# [[896   0]
#  [  0 138]]
# 1.0

# %%
dt.fit(x_train,y_train)
y_pred4=dt.predict(x_test)
print(accuracy_score(y_test,y_pred4))
print(confusion_matrix(y_test,y_pred4))
print(precision_score(y_test,y_pred4))
# Out:
# 1.0
# [[896   0]
#  [  0 138]]
# 1.0

# %%
rf.fit(x_train,y_train)
y_pred5=rf.predict(x_test)
print(accuracy_score(y_test,y_pred5))
print(confusion_matrix(y_test,y_pred5))
print(precision_score(y_test,y_pred5))
# Out:
# 1.0
# [[896   0]
#  [  0 138]]
# 1.0

# %%
sc.fit(x_train,y_train)
y_pred6=sc.predict(x_test)
print(accuracy_score(y_test,y_pred6))
print(confusion_matrix(y_test,y_pred6))
print(precision_score(y_test,y_pred6))
# Out:
# 1.0
# [[896   0]
#  [  0 138]]
# 1.0

# %%
Ada.fit(x_train,y_train)
y_pred7=Ada.predict(x_test)
print(accuracy_score(y_test,y_pred7))
print(confusion_matrix(y_test,y_pred7))
print(precision_score(y_test,y_pred7))
# Out:
# 1.0
# [[896   0]
#  [  0 138]]
# 1.0
# c:\Users\jhama\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %%
ET.fit(x_train,y_train)
y_pred8=ET.predict(x_test)
print(accuracy_score(y_test,y_pred8))
print(confusion_matrix(y_test,y_pred8))
print(precision_score(y_test,y_pred8))
# Out:
# 1.0
# [[896   0]
#  [  0 138]]
# 1.0

# %%
clfs={
  'SVC':sc,
  'NB':mnb,
  'DT':dt,
  'RF':rf,
  'Ada':Ada,
  'ET':ET
}

# %%
def train_classifier(clf,x_train,y_train,x_test,y_test):
  clf.fit(x_train,y_train)
  y_pred=clf.predict(x_test)
  accuracy=accuracy_score(y_test,y_pred)
  precision=precision_score(y_test,y_pred)

  return accuracy.precision

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))

# %%
pickle.load(open("model.pkl","rb"))
# Out:
# MultinomialNB()
